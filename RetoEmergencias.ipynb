# %%
import numpy as np
import pandas as pd
import re
import math
from pyproj import Proj
import datetime


emergencies = pd.read_csv('../datasets/emergencies.csv', sep=';')
averias = pd.read_csv('../datasets/averias.csv', sep=';')
reclamaciones = pd.read_csv('../datasets/reclamaciones.csv', sep= ';')
averias_bcn = pd.read_csv("../datasets/averias_dis.csv", sep=",")
# Out:
# /Users/ireneroma/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
accidentes.head(10)
# Out:
#           dist   any  mes  dia  hora      Long        Lat
# 0  Sant Mart�_  2016    4    5    10  2.186566  41.412487
# 1  Sant Mart�_  2016    2   13    14  2.186565  41.412595
# 2  Sant Mart�_  2016   12   15     8  2.183345  41.416527
# 3  Sant Mart�_  2016    5   20    13  2.184785  41.416204
# 4  Sant Mart�_  2016    5   31     0  2.177437  41.413377
# 5  Sant Mart�_  2016   12   24     5  2.180602  41.414823
# 6  Sant Mart�_  2016    6   14     9  2.180391  41.415434
# 7  Sant Mart�_  2016   12   17    10  2.177640  41.410550
# 8  Sant Mart�_  2016    5    8    17  2.178164  41.410806
# 9  Sant Mart�_  2016   11   11    16  2.180769  41.412924

# %%
bomberos = consumos[consumos.tipo=='SERVEI EQUIP C.INCENDIS']
beixample = bomberos[bomberos.dis=='EIXAMPLE']
beixample.ano = pd.to_numeric(beixample.ano)
comercial = beixample[beixample.uso=='INDUSTRIAL']

# %%
comercial.sort(['ano','mun','dis','uso','tipo','consumo','contratos'], ascending=[True, False, False, False, False, False, False]).head()
# Out:
# /Users/ireneroma/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#           ano        mun           dis         uso                     tipo  \
# 8627   201103  BARCELONA  CIUTAT VELLA  INDUSTRIAL  SERVEI EQUIP C.INCENDIS
# 10306  201105  BARCELONA  CIUTAT VELLA  INDUSTRIAL  SERVEI EQUIP C.INCENDIS
# 8694   201201  BARCELONA  CIUTAT VELLA  INDUSTRIAL  SERVEI EQUIP C.INCENDIS
# 10379  201203  BARCELONA  CIUTAT VELLA  INDUSTRIAL  SERVEI EQUIP C.INCENDIS
# 10639  201211  BARCELONA  CIUTAT VELLA  INDUSTRIAL  SERVEI EQUIP C.INCENDIS
#
#        consumo  contratos
# 8627         0      105.0
# 10306        0        1.0
# 8694         0        3.0
# 10379        0      107.0
# 10639        0        1.0

# %%
aeixample = accidentes[accidentes.dist=="Eixample"]
aeixample["date"] = aeixample["dia"].map(str) + str("-") + aeixample["mes"].map(str) + str("-") + aeixample["any"].map(str)
# Out:
# /Users/ireneroma/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
aeixample
# Out:
#            dist   any  mes  dia  hora      Long        Lat        date
# 217    Eixample  2016    7   11    16  2.153138  41.376306   11-7-2016
# 218    Eixample  2016    1   24     0  2.154036  41.377160   24-1-2016
# 220    Eixample  2016   12   13    11  2.154809  41.376580  13-12-2016
# 221    Eixample  2016    7   27    14  2.154507  41.376803   27-7-2016
# 222    Eixample  2016    6   16    18  2.154507  41.376803   16-6-2016
# 223    Eixample  2016    3    8    16  2.154507  41.376803    8-3-2016
# 228    Eixample  2016    4    9    12  2.153798  41.375194    9-4-2016
# 229    Eixample  2016    1   27    10  2.152818  41.375196   27-1-2016
# 230    Eixample  2016    8   24    21  2.152733  41.376177   24-8-2016
# 231    Eixample  2016   10    7    19  2.146197  41.386767   7-10-2016
# 232    Eixample  2016    7    6    20  2.164968  41.375159    6-7-2016
# 233    Eixample  2016    8    3    17  2.162815  41.375170    3-8-2016
# 234    Eixample  2016    5    5    13  2.158521  41.381768    5-5-2016
